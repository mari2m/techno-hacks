# %% [markdown]
# # Task3:Visualization using Histogram

# %% [markdown]
# data set:Titanic - Machine Learning from Disaster that Predict survival on the Titanic and get familiar with ML basics

# %% [markdown]
# target--> Create a histogram or bar chart to visualize the distribution of data in a dataset

# %%
import numpy as np 
import pandas as pd 
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("train.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.shape
# Out:
# (891, 12)

# %%
df.info
# Out:
# <bound method DataFrame.info of      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ...

# %%
df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
categorical_cols = df.select_dtypes(include=['object']).columns
numerical_cols = df.select_dtypes(include=['int64', 'float64']).columns

# %%
categorical_cols , numerical_cols
# Out:
# (Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object'),
#  Index(['PassengerId', 'Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare'], dtype='object'))

# %%
df['Age'].value_counts()
# Out:
# 24.00    30
# 22.00    27
# 18.00    26
# 19.00    25
# 28.00    25
#          ..
# 36.50     1
# 55.50     1
# 0.92      1
# 23.50     1
# 74.00     1
# Name: Age, Length: 88, dtype: int64

# %%
df['Sex'].value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
df['Fare'].value_counts()
# Out:
# 8.0500     43
# 13.0000    42
# 7.8958     38
# 7.7500     34
# 26.0000    31
#            ..
# 35.0000     1
# 28.5000     1
# 6.2375      1
# 14.0000     1
# 10.5167     1
# Name: Fare, Length: 248, dtype: int64

# %%
df['Ticket'].value_counts()
# Out:
# 347082      7
# CA. 2343    7
# 1601        7
# 3101295     6
# CA 2144     6
#            ..
# 9234        1
# 19988       1
# 2693        1
# PC 17612    1
# 370376      1
# Name: Ticket, Length: 681, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
for column in numerical_cols:
    plt.figure(figsize=(8, 4))
    sns.histplot(df[column], kde=True)
    plt.title(f'Distribution of {column}')
    plt.xlabel(column)
    plt.ylabel('Frequency')
    plt.show()

# %%
for column in numerical_cols:
    plt.figure(figsize=(8, 4))
    sns.histplot(df[column], kde=True)
    plt.title(f'Distribution of {column}')
    plt.xlabel(column)
    plt.ylabel('Frequency')
    plt.show()

# %%
# Plotting for categorical columns
for column in categorical_cols:
    plt.figure(figsize=(8, 4))
    sns.countplot(x=df[column])
    plt.title(f'Count of Categories in {column}')
    plt.ylabel('Count')
    plt.show()

# %%
for i in ['Age', 'Fare']:
    died = list(df[df['Survived'] == 0][i].dropna())
    survived = list(df[df['Survived'] == 1][i].dropna())
    xmin =min(min(died), min(survived))
    xmax = max(max(died ), max(survived))
    width = (xmax -xmin) / 40
    sns.distplot(died, color = 'r', kde = False, bins= np.arange(xmin, xmax, width ))
    sns.distplot(survived, color = 'g', kde = False, bins = np.arange(xmin,xmax, width))
    plt.legend(['Did not survive', 'Survived'])
    plt.title('Overlaid histogram for {}'.format(i))
    plt.show()
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# Gender countplot visualization
sns.displot(x=df['Sex'], hue=df['Survived'])
plt.show()

# %%
sns.displot(df, x="Survived", hue="Cabin", element="step")
plt.show()

# %%
df['Cabin'] = df['Cabin'].astype(str)
df['Survived'] = df['Survived'].astype(str)
copy_df = df.copy()
copy_df['Cabin_Group'] = df['Cabin'].str[0]

plt.figure(figsize=(7,4))
sns.countplot(x=copy_df['Cabin_Group'], hue=copy_df['Survived'], palette='deep')
plt.title("# of Survivors in Each Cabin Group")
plt.tight_layout()
plt.show()

# %%
sns.displot(df, x="Pclass", kind="kde")#'hist', 'kde', 'ecdf'
plt.show()

# %%
sns.displot(df, x="Pclass", kind="ecdf")

# %%
counts=df['Survived'].value_counts()

# %%
counts_to_list=counts.index.values.tolist()

# %%
plt.pie(counts,labels=counts_to_list)
plt.show()

# %%
hm=df[numerical_cols].corr()

# %%
fig,ax = plt.subplots(figsize=(12,4))
sns.heatmap(hm,cmap='Blues')
ax.set_title('Simple Heatmap')
# Out:
# Text(0.5, 1.0, 'Simple Heatmap')
